# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <!-- ## Non matrix form derivation
#
# y = mx+c
#
# $ RSS = \frac{(y- y^)^{2}}{2N} $
# <!--     = (y- (mx+c))^{2}  -->
#
# $ \frac{\delta RSS}{\delta m} = \sum{2(y- (mx+c))x} $
#
# $ \frac{\delta RSS}{\delta c} = \sum{2(y- (mx+c))} $
#
#  -->

# %% [markdown]
# ## Matrix Derivation
#
# $ y = \theta^{T}X $
#
#
# $$ RSS = \frac{1}{2m}(y-\hat y)^{T}(y-\hat y) $$
# $$ RSS = \frac{1}{2m}(X{\theta}-y)^{T}(X{\theta}-y) $$
# $$ RSS = \frac{1}{2m}((X\theta )^{T}-y^{T})(X{\theta}-y) $$
# $$ RSS = \frac{1}{2m}( \theta^{T}X^{T}X{\theta}-2\theta^{T}X^{T}y+y^{T}y) $$
#
# $$ \frac{\delta RSS}{\delta \theta} = \frac{2}{2m}(\theta^{T}𝑋𝑇X-X^{T}y ) $$
# $$ \frac{\delta RSS}{\delta \theta} = \frac{2}{2m}(\hat y - y )X^{T} $$
#
#
# For the weight update
#
# $$  \theta = \theta - \frac{\delta MSE}{\delta \theta} $$
# $$  \theta = \theta - \alpha(\frac{1}{m}(\hat y - y )X^{T})  $$
#
# $$ \boxed{ \theta = \theta + \frac{\alpha}{m}(y - \hat y)X^{T} } $$
